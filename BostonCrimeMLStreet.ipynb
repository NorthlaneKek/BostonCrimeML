# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv('crime.csv', sep = ',', engine = 'python', error_bad_lines=False)

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data['OFFENSE_CODE_GROUP'].unique()
# Out:
# array(['Verbal Disputes', 'Investigate Property', 'Larceny', 'Towed',
#        'Property Lost', 'Other', 'Investigate Person',
#        'Aggravated Assault', 'Vandalism', 'Drug Violation',
#        'Medical Assistance', 'Harassment', 'Residential Burglary',
#        'Simple Assault', 'Motor Vehicle Accident Response',
#        'Confidence Games', 'Landlord/Tenant Disputes',
#        'Larceny From Motor Vehicle', 'Prisoner Related Incidents',
#        'Fraud', 'Police Service Incidents', 'Auto Theft', 'Service',
#        'Robbery', 'Firearm Violations',
#        'Assembly or Gathering Violations', 'Fire Related Reports',
#        'Violations', 'Aircraft', 'Auto Theft Recovery',
#        'Missing Person Reported', 'Firearm Discovery', 'Warrant Arrests',
#        'Recovered Stolen Property', 'Missing Person Located',
#        'Property Found', 'Ballistics', 'Harbor Related Incidents',
#        'License Violation', 'Operating Under the Influence',
#        'Search Warrants', 'Disorderly Conduct', 'Other Burglary',
#        'Criminal Harassment', 'Prostitution',
#        'Restraining Order Violations', 'Explosives',
#        'Property Related Damage', 'Commercial Burglary', 'Embezzlement',
#        'Counterfeiting', 'Liquor Violation',
#        'Offenses Against Child / Family',
#        'License Plate Related Incidents', 'HOME INVASION', 'Homicide',
#        'Evading Fare', 'Arson', 'Phone Call Complaints', 'Bomb Hoax'],
#       dtype=object)

# %%
data = data[
    (data['OFFENSE_CODE_GROUP'] == 'Drug Violation') |
    (data['OFFENSE_CODE_GROUP'] == 'Investigate Person') |
    (data['OFFENSE_CODE_GROUP'] == 'Simple Assault') |
    (data['OFFENSE_CODE_GROUP'] == 'Towed') |
    (data['OFFENSE_CODE_GROUP'] == 'Vandalism') |
    (data['OFFENSE_CODE_GROUP'] == 'Verbal Disputes') |
    (data['OFFENSE_CODE_GROUP'] == 'Property Lost')]

# %%
data['OFFENSE_CODE_GROUP'].unique()
# Out:
# array(['Verbal Disputes', 'Towed', 'Property Lost', 'Investigate Person',
#        'Vandalism', 'Drug Violation', 'Simple Assault'], dtype=object)

# %%
data['DISTRICT'].unique()
# Out:
# array(['B3', 'C6', 'D14', 'E13', nan, 'B2', 'E5', 'D4', 'C11', 'A1',
#        'E18', 'A7', 'A15'], dtype=object)

# %%
print(data)
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I182054381          3301     Verbal Disputes
# 4          I182054374          3410               Towed
# 5          I182054372          3201       Property Lost
# 7          I182054369          3115  Investigate Person
# 8          I182054368          3115  Investigate Person
# 14         I182054360          3115  Investigate Person
# 15         I182054358          1402           Vandalism
# 17         I182054356          1810      Drug Violation
# 18         I182054356          1843      Drug Violation
# 19         I182054356          1849      Drug Violation
# 22         I182054352          3115  Investigate Person
# 27         I182054346          1402           Vandalism
# 28         I182054345          3301     Verbal Disputes
# 33         I182054337          3301     Verbal Disputes
# 35         I182054334          3115  Investigate Person
# 36         I182054333           802      Simple Assault
# 37         I182054331           802      Simple Assault
# 38         I182054330          3115  Investigate Person
# 40         I182054328          3115  Investigate Person
# 42         I182054326          3115  Investigate Person
# 49         I182054317          3115  Investigate Person
# 50         I182054316          1842      Drug Violation
# 52         I182054314          1841      Drug Violation
# 53         I182054314          1843      Drug Violation
# 55         I182054312          3410               Towed
# 58         I182054308          3115  Investigate Person
# 60         I182054306          3115  Investigate Person
# 62         I182054304           802      Simple Assault
# 64         I182054302          3301     Verbal Disputes
# 70         I182054296           802      Simple Assault
# ...               ...           ...                 ...
# 41246      I182010137          3201       Property Lost
# 41247      I182010135          3115  Investigate Person
# 41248      I182010132          1806      Drug Violation
# 41251      I182010128          1849      Drug Violation
# 41252      I182010127          3301     Verbal Disputes
# 41255      I182010123          1402           Vandalism
# 41256      I182010123          3301     Verbal Disputes
# 41262      I182010116          3115  Investigate Person
# 41265      I182010113          1402           Vandalism
# 41266      I182010112          3301     Verbal Disputes
# 41273      I182010103          1841      Drug Violation
# 41274      I182010102          3201       Property Lost
# 41275      I182010101          3115  Investigate Person
# 41283      I182010091          3201       Property Lost
# 41290      I182010082          3201       Property Lost
# 41291      I182010081           802      Simple Assault
# 41292      I182010080          3115  Investigate Person
# 41294      I182010077          3301     Verbal Disputes
# 41304      I182010068          3201       Property Lost
# 41309      I182010062          3301     Verbal Disputes
# 41312      I182010058          1841      Drug Violation
# 41313      I182010058          3115  Investigate Person
# 41316      I182010055          3301     Verbal Disputes
# 41318      I182010053           802      Simple Assault
# 41320      I182010048          1402           Vandalism
# 41321      I182010047          1845      Drug Violation
# 41329      I182010039          3201       Property Lost
# 41333      I182010033          3201       Property Lost
# 41334      I182010032          3115  Investigate Person
# 41336      I182010030          1849      Drug Violation
#
#                                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                                      VERBAL DISPUTE       B3            428
# 4                                 TOWED MOTOR VEHICLE       C6            211
# 5                                     PROPERTY - LOST       C6            186
# 7                                  INVESTIGATE PERSON      D14            788
# 8                                  INVESTIGATE PERSON      E13            571
# 14                                 INVESTIGATE PERSON      NaN
# 15                                          VANDALISM       B2            319
# 17                       DRUGS - SALE / MANUFACTURING      NaN
# 18     DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP      NaN
# 19               DRUGS - POSS CLASS B - COCAINE, ETC.      NaN
# 22                                 INVESTIGATE PERSON       E5            559
# 27                                          VANDALISM       B2            312
# 28                                     VERBAL DISPUTE       D4            158
# 33                                     VERBAL DISPUTE       C6            231
# 35                                 INVESTIGATE PERSON      C11            823
# 36                           ASSAULT SIMPLE - BATTERY       B3            421
# 37                           ASSAULT SIMPLE - BATTERY       D4            138
# 38                                 INVESTIGATE PERSON       D4            273
# 40                                 INVESTIGATE PERSON       D4            903
# 42                                 INVESTIGATE PERSON       A1            111
# 49                                 INVESTIGATE PERSON       E5            563
# 50               DRUGS - POSS CLASS A - HEROIN, ETC.        C6            175
# 52     DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       C6            177
# 53     DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       C6            177
# 55                                TOWED MOTOR VEHICLE       D4            149
# 58                                 INVESTIGATE PERSON       B2            257
# 60                                 INVESTIGATE PERSON       B3            406
# 62                           ASSAULT SIMPLE - BATTERY       B3            458
# 64                                     VERBAL DISPUTE       D4            903
# 70                           ASSAULT SIMPLE - BATTERY       D4            632
# ...                                               ...      ...            ...
# 41246                                 PROPERTY - LOST      A15
# 41247                              INVESTIGATE PERSON      E18            957
# 41248       DRUGS - CLASS B TRAFFICKING OVER 18 GRAM
# 19       Part Two                NaN  42.352389 -71.062603
# 22     Part Three          ALBANO ST  42.283426 -71.131374
# 27       Part Two       HOLLANDER ST  42.315689 -71.089514
# 28     Part Three       AGUADILLA ST  42.341893 -71.074083
# 33     Part Three         E SIXTH ST  42.333212 -71.030181
# 35     Part Three        CUSHING AVE  42.313457 -71.062710
# 36       Part Two       BANFIELD AVE  42.276843 -71.087595
# 37       Part Two        BOYLSTON ST  42.349325 -71.080148
# 38     Part Three        SHAWMUT AVE  42.337012 -71.078538
# 40     Part Three       LATTIMORE CT  42.336766 -71.082051
# 42     Part Three           AVERY ST  42.353302 -71.063780
# 49     Part Three        FAWNDALE RD  42.290118 -71.121879
# 50       Part Two          TOPEKA ST  42.332809 -71.067292
# 52       Part Two  MASSACHUSETTS AVE  42.331521 -71.070853
# 53       Part Two  MASSACHUSETTS AVE  42.331521 -71.070853
# 55     Part Three       COLUMBUS AVE  42.344023 -71.077549
# 58     Part Three        COLUMBIA RD  42.315969 -71.066253
# 60     Part Three           RIVER ST  42.270615 -71.086555
# 62       Part Two         WOLCOTT ST  42.302736 -71.082485
# 64     Part Three         HAMMOND ST  42.335954 -71.083014
# 70       Part Two       BAY STATE RD  42.350652 -71.103841
# ...           ...                ...        ...        ...
# 41246  Part Three         RUTHERFORD  -1.000000  -1.000000
# 41247  Part Three       CLIFFMONT ST  42.276682 -71.120653
# 41248    Part Two         BOWDOIN ST        NaN        NaN
# 41251    Part Two          MORTON ST  42.277543 -71.077950
# 41252  Part Three     WILMINGTON AVE  42.280292 -71.072206
# 41255    Part Two      BLAKEVILLE ST  42.304706 -71.070915
# 41256  Part Three      BLAKEVILLE ST  42.304706 -71.070915
# 41262  Part Three           PRATT ST  42.355011 -71.128879
# 41265    Part Two         E FIFTH ST  42.333989 -71.032606
# 41266  Part Three        MARGINAL ST  42.367286 -71.040417
# 41273    Part Two         W BROADWAY  42.341288 -71.054679
# 41274  Part Three           UNION ST  42.361482 -71.057191
# 41275  Part Three         TREMONT ST  42.337380 -71.083889
# 41283  Part Three           RIVER ST  42.271710 -71.078161
# 41290  Part Three           AVERY ST  42.353260 -71.062832
# 41291    Part Two     DORCHESTER AVE  42.329717 -71.056968
# 41292  Part Three            WELD ST  42.291834 -71.159141
# 41294  Part Three          FULLER ST  42.280728 -71.077136
# 41304  Part Three        SARATOGA ST  42.386855 -71.007383
# 41309  Part Three       W SEVENTH ST  42.336979 -71.055003
# 41312    Part Two        ROCKWELL ST  42.283875 -71.071550
# 41313  Part Three        ROCKWELL ST  42.283875 -71.071550
# 41316  Part Three      RUSKINDALE RD  42.268897 -71.108137
# 41318    Part Two    MICHELANGELO ST  42.367089 -71.054811
# 41320    Part Two          FALCON ST  42.381962 -71.031845
# 41321    Part Two         MCBRIDE ST  42.305815 -71.109627
# 41329  Part Three           BROAD ST  42.358509 -71.054297
# 41333  Part Three  MASSACHUSETTS AVE  42.327800 -71.067710
# 41334  Part Three        HIGHLAND ST  42.323410 -71.093396
# 41336    Part Two         BOWDOIN ST  42.305534 -71.067885
#
#                           Location
# 0      (42.28282878, -71.09182490)
# 4      (42.33896439, -71.04896420)
# 5      (42.32696647, -71.06198607)
# 7      (42.33996911, -71.15048615)
# 8      (42.31190641, -71.10213227)
# 14      (-1.00000000, -1.00000000)
# 15     (42.30845311, -71.08718664)
# 17     (42.35238871, -71.06260312)
# 18     (42.35238871, -71.06260312)
# 19     (42.35238871, -71.06260312)
# 22     (42.28342598, -71.13137374)
# 27     (42.31568920, -71.08951391)
# 28     (42.34189304, -71.07408312)
# 33     (42.33321208, -71.03018110)
# 35     (42.31345710, -71.06271009)
# 36     (42.27684317, -71.08759512)
# 37     (42.34932471, -71.08014801)
# 38     (42.33701214, -71.07853797)
# 40     (42.33676619, -71.08205122)
# 42     (42.35330197, -71.06377969)
# 49     (42.29011783, -71.12187904)
# 50     (42.33280882, -71.06729226)
# 52     (42.33152148, -71.07085307)
# 53     (42.33152148, -71.07085307)
# 55     (42.34402350, -71.07754900)
# 58     (42.31596900, -71.06625300)
# 60     (42.27061469, -71.08655479)
# 62     (42.30273607, -71.08248544)
# 64     (42.33595449, -71.08301373)
# 70     (42.35065232, -71.10384116)
# ...                            ...
# 41246   (-1.00000000, -1.00000000)
# 41247  (42.27668221, -71.12065268)
# 41248     (0.00000000, 0.00000000)
# 41251  (42.27754320, -71.07795019)
# 41252  (42.28029155, -71.07220576)
# 41255  (42.30470597, -71.07091547)
# 41256  (42.30470597, -71.07091547)
# 41262  (42.35501072, -71.12887911)
# 41265  (42.33398889, -71.03260574)
# 41266  (42.36728587, -71.04041697)
# 41273  (42.34128751, -71.05467933)
# 41274  (42.36148163, -71.05719146)
# 41275  (42.33738014, -71.08388901)
# 41283  (42.27171028, -71.07816110)
# 41290  (42.35326010, -71.06283216)
# 41291  (42.32971683, -71.05696834)
# 41292  (42.29183428, -71.15914058)
# 41294  (42.28072751, -71.07713631)
# 41304  (42.38685489, -71.00738288)
# 41309  (42.33697857, -71.05500277)
# 41312  (42.28387495, -71.07154989)
# 41313  (42.28387495, -71.07154989)
# 41316  (42.26889666, -71.10813750)
# 41318  (42.36708890, -71.05481065)
# 41320  (42.38196242, -71.03184460)
# 41321  (42.30581531, -71.10962700)
# 41329  (42.35850919, -71.05429726)
# 41333  (42.32779976, -71.06771009)
# 41334  (42.32340986, -71.09339604)
# 41336  (42.30553434, -71.06788511)
#
# [13497 rows x 17 columns]

# %%
data['OFFENSE_CODE_GROUP'].unique()
# Out:
# array(['Verbal Disputes', 'Towed', 'Property Lost', 'Investigate Person',
#        'Vandalism', 'Drug Violation', 'Simple Assault'], dtype=object)

# %%
data.tail()
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 41321      I182010047          1845      Drug Violation
# 41329      I182010039          3201       Property Lost
# 41333      I182010033          3201       Property Lost
# 41334      I182010032          3115  Investigate Person
# 41336      I182010030          1849      Drug Violation
#
#                         OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 41321                  DRUGS - POSS CLASS D      E13            573      NaN
# 41329                       PROPERTY - LOST       A1            100      NaN
# 41333                       PROPERTY - LOST       C6            177      NaN
# 41334                    INVESTIGATE PERSON       B2            300      NaN
# 41336  DRUGS - POSS CLASS B - COCAINE, ETC.      C11            341      NaN
#
#           OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR    UCR_PART  \
# 41321  2018-02-06 12:50:00  2018      2     Tuesday    12    Part Two
# 41329  2018-02-03 23:00:00  2018      2    Saturday    23  Part Three
# 41333  2018-01-15 00:00:00  2018      1      Monday     0  Part Three
# 41334  2017-03-01 00:00:00  2017      3   Wednesday     0  Part Three
# 41336  2018-02-07 11:36:00  2018      2   Wednesday    11    Part Two
#
#                   STREET        Lat       Long                     Location
# 41321         MCBRIDE ST  42.305815 -71.109627  (42.30581531, -71.10962700)
# 41329           BROAD ST  42.358509 -71.054297  (42.35850919, -71.05429726)
# 41333  MASSACHUSETTS AVE  42.327800 -71.067710  (42.32779976, -71.06771009)
# 41334        HIGHLAND ST  42.323410 -71.093396  (42.32340986, -71.09339604)
# 41336         BOWDOIN ST  42.305534 -71.067885  (42.30553434, -71.06788511)

# %%
data.corr(method='pearson')
# Out:
#               OFFENSE_CODE      YEAR     MONTH      HOUR       Lat      Long
# OFFENSE_CODE      1.000000 -0.035603 -0.010242 -0.051800 -0.006049  0.005125
# YEAR             -0.035603  1.000000 -0.217344  0.031517  0.044454 -0.044290
# MONTH            -0.010242 -0.217344  1.000000  0.009332 -0.012084  0.011801
# HOUR             -0.051800  0.031517  0.009332  1.000000  0.028824 -0.029873
# Lat              -0.006049  0.044454 -0.012084  0.028824  1.000000 -0.999846
# Long              0.005125 -0.044290  0.011801 -0.029873 -0.999846  1.000000

# %%
print(data.shape)
print(data.columns)
# Out:
# (13497, 17)
# Index(['INCIDENT_NUMBER', 'OFFENSE_CODE', 'OFFENSE_CODE_GROUP',
#        'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'SHOOTING',
#        'OCCURRED_ON_DATE', 'YEAR', 'MONTH', 'DAY_OF_WEEK', 'HOUR', 'UCR_PART',
#        'STREET', 'Lat', 'Long', 'Location'],
#       dtype='object')

# %%
#data.columns = []

# %%
data.index
# Out:
# Int64Index([    0,     4,     5,     7,     8,    14,    15,    17,    18,
#                19,
#             ...
#             41312, 41313, 41316, 41318, 41320, 41321, 41329, 41333, 41334,
#             41336],
#            dtype='int64', length=13497)

# %%
data['DAY_OF_WEEK'].tail()
# Out:
# 41321      Tuesday
# 41329     Saturday
# 41333       Monday
# 41334    Wednesday
# 41336    Wednesday
# Name: DAY_OF_WEEK, dtype: object

# %%
data['DAY_OF_WEEK'].dtype.name
# Out:
# 'object'

# %%
type(data['MONTH'])
# Out:
# pandas.core.series.Series

# %%
data[['DAY_OF_WEEK', 'STREET']].head()
# Out:
#   DAY_OF_WEEK         STREET
# 0     Tuesday  BLUE HILL AVE
# 4     Tuesday     W THIRD ST
# 5     Tuesday    ALLSTATE RD
# 7     Tuesday    CHISWICK RD
# 8     Tuesday  WASHINGTON ST

# %%
#data.index = xrange(32561)
#data.index

# %%
data.describe()
# Out:
#        OFFENSE_CODE          YEAR         MONTH          HOUR           Lat  \
# count  13497.000000  13497.000000  13497.000000  13497.000000  12836.000000
# mean    2389.703267   2017.993702      4.407128     13.181077     42.189089
# std     1003.015530      0.085416      1.550184      6.258755      2.384556
# min      801.000000   2015.000000      1.000000      0.000000     -1.000000
# 25%     1402.000000   2018.000000      3.000000      9.000000     42.295484
# 50%     3115.000000   2018.000000      4.000000     14.000000     42.321836
# 75%     3301.000000   2018.000000      6.000000     18.000000     42.346271
# max     3410.000000   2018.000000     12.000000     23.000000     42.395042
#
#                Long
# count  12836.000000
# mean     -70.869965
# std        3.857432
# min      -71.173076
# 25%      -71.096068
# 50%      -71.077706
# 75%      -71.062971
# max       -1.000000

# %%
# This scatter_matrix is useless from my point of view. Dataset doesn't contain numerical values. The intention was in trying
# to use this function. Sorry.
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = 0.05, figsize = (10,10))
pass

# %%
data.corr()
# Out:
#               OFFENSE_CODE      YEAR     MONTH      HOUR       Lat      Long
# OFFENSE_CODE      1.000000 -0.035603 -0.010242 -0.051800 -0.006049  0.005125
# YEAR             -0.035603  1.000000 -0.217344  0.031517  0.044454 -0.044290
# MONTH            -0.010242 -0.217344  1.000000  0.009332 -0.012084  0.011801
# HOUR             -0.051800  0.031517  0.009332  1.000000  0.028824 -0.029873
# Lat              -0.006049  0.044454 -0.012084  0.028824  1.000000 -0.999846
# Long              0.005125 -0.044290  0.011801 -0.029873 -0.999846  1.000000

# %%
#I don't see there any logical values, so I will take two random values just to test functions
plt.plot(data['OFFENSE_CODE'], data['YEAR'], 'o', alpha = 0.05)
plt.xlabel('OFFENSE_CODE')
plt.ylabel('YEAR')
plt.title('X vs Y')
pass

# %%
data[data['OFFENSE_DESCRIPTION'] == 'ASSAULT']
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER, OFFENSE_CODE, OFFENSE_CODE_GROUP, OFFENSE_DESCRIPTION, DISTRICT, REPORTING_AREA, SHOOTING, OCCURRED_ON_DATE, YEAR, MONTH, DAY_OF_WEEK, HOUR, UCR_PART, STREET, Lat, Long, Location]
# Index: []

# %%
data[data['OFFENSE_DESCRIPTION'] == 'ASSAULT - AGGRAVATED - BATTERY']
# Out:
# Empty DataFrame
# Columns: [INCIDENT_NUMBER, OFFENSE_CODE, OFFENSE_CODE_GROUP, OFFENSE_DESCRIPTION, DISTRICT, REPORTING_AREA, SHOOTING, OCCURRED_ON_DATE, YEAR, MONTH, DAY_OF_WEEK, HOUR, UCR_PART, STREET, Lat, Long, Location]
# Index: []

# %%
# Trying to add some logic in my lab work.
# X - District
# Y - Day of the week (sorted)
# We are trying to see how do the assault of different types (with battery/non battery used) are spread during the week.
plt.figure(figsize = (17, 6))

plt.scatter(data[data['HOUR'] == 15]['OFFENSE_CODE_GROUP'],
            data[data['HOUR'] == 15]['MONTH'],
            alpha = 0.15,
            label = 'Any criminal actions at 3 P.M.',
            color = 'r')

plt.scatter(data[data['HOUR'] == 22]['OFFENSE_CODE_GROUP'],
            data[data['HOUR'] == 22]['MONTH'],
            alpha = 0.15,
            label = 'Any criminal actions at 10 P.M',
            color = 'b')

plt.xlabel('OFFENSE CODE GROUP')
plt.xticks(range(18))
plt.xlim(0, 17)
plt.ylabel('MONTH')
plt.legend()
plt.grid()

# %%
plt.figure(figsize = (17, 6))

plt.scatter(data[data['HOUR'] == 15]['OFFENSE_CODE_GROUP'],
            data[data['HOUR'] == 15]['MONTH'],
            alpha = 0.15,
            label = 'Any criminal actions at 3 P.M.',
            color = 'r')

plt.scatter(data[data['HOUR'] == 22]['OFFENSE_CODE_GROUP'],
            data[data['HOUR'] == 22]['MONTH'],
            alpha = 0.15,
            label = 'Any criminal actions at 10 P.M',
            color = 'b')

plt.xlabel('OFFENSE CODE GROUP')
plt.ylabel('MONTH')
plt.legend()
plt.grid()
pass

# %% [markdown]
# Нечисловые признаки

# %%
data.describe(include = ['object'])
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION DISTRICT  \
# count            13497               13497               13497    13403
# unique           12845                   7                  32       12
# top         I182051950  Investigate Person  INVESTIGATE PERSON       B2
# freq                 5                2436                2436     2056
#
#        REPORTING_AREA SHOOTING     OCCURRED_ON_DATE DAY_OF_WEEK    UCR_PART  \
# count           13497        4                13497       13497       13497
# unique            837        1                11958           7           2
# top                          Y  2018-01-01 00:00:00      Friday  Part Three
# freq              743        4                    8        2059        7491
#
#                STREET                  Location
# count           13312                     13497
# unique           2030                      5407
# top     WASHINGTON ST  (0.00000000, 0.00000000)
# freq              626                       661

# %%
data.describe(include = 'all')
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION  \
# count            13497  13497.000000               13497               13497
# unique           12845           NaN                   7                  32
# top         I182051950           NaN  Investigate Person  INVESTIGATE PERSON
# freq                 5           NaN                2436                2436
# mean               NaN   2389.703267                 NaN                 NaN
# std                NaN   1003.015530                 NaN                 NaN
# min                NaN    801.000000                 NaN                 NaN
# 25%                NaN   1402.000000                 NaN                 NaN
# 50%                NaN   3115.000000                 NaN                 NaN
# 75%                NaN   3301.000000                 NaN                 NaN
# max                NaN   3410.000000                 NaN                 NaN
#
#        DISTRICT REPORTING_AREA SHOOTING     OCCURRED_ON_DATE          YEAR  \
# count     13403          13497        4                13497  13497.000000
# unique       12            837        1                11958           NaN
# top          B2                       Y  2018-01-01 00:00:00           NaN
# freq       2056            743        4                    8           NaN
# mean        NaN            NaN      NaN                  NaN   2017.993702
# std         NaN            NaN      NaN                  NaN      0.085416
# min         NaN            NaN      NaN                  NaN   2015.000000
# 25%         NaN            NaN      NaN                  NaN   2018.000000
# 50%         NaN            NaN      NaN                  NaN   2018.000000
# 75%         NaN            NaN      NaN                  NaN   2018.000000
# max         NaN            NaN      NaN                  NaN   2018.000000
#
#                MONTH DAY_OF_WEEK          HOUR    UCR_PART         STREET  \
# count   13497.000000       13497  13497.000000       13497          13312
# unique           NaN           7           NaN           2           2030
# top              NaN      Friday           NaN  Part Three  WASHINGTON ST
# freq             NaN        2059           NaN        7491            626
# mean        4.407128         NaN     13.181077         NaN            NaN
# std         1.550184         NaN      6.258755         NaN            NaN
# min         1.000000         NaN      0.000000         NaN            NaN
# 25%         3.000000         NaN      9.000000         NaN            NaN
# 50%         4.000000         NaN     14.000000         NaN            NaN
# 75%         6.000000         NaN     18.000000         NaN            NaN
# max        12.000000         NaN     23.000000         NaN            NaN
#
#                  Lat          Long                  Location
# count   12836.000000  12836.000000                     13497
# unique           NaN           NaN                      5407
# top              NaN           NaN  (0.00000000, 0.00000000)
# freq             NaN           NaN                       661
# mean       42.189089    -70.869965                       NaN
# std         2.384556      3.857432                       NaN
# min        -1.000000    -71.173076                       NaN
# 25%        42.295484    -71.096068                       NaN
# 50%        42.321836    -71.077706                       NaN
# 75%        42.346271    -71.062971                       NaN
# max        42.395042     -1.000000                       NaN

# %% [markdown]
# Уникальные значения деталей преступления:

# %%
data['OFFENSE_DESCRIPTION'].unique()
# Out:
# array(['VERBAL DISPUTE', 'TOWED MOTOR VEHICLE', 'PROPERTY - LOST',
#        'INVESTIGATE PERSON', 'VANDALISM', 'DRUGS - SALE / MANUFACTURING',
#        'DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP',
#        'DRUGS - POSS CLASS B - COCAINE, ETC.', 'ASSAULT SIMPLE - BATTERY',
#        'DRUGS - POSS CLASS A - HEROIN, ETC. ',
#        'DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP',
#        'DRUGS - POSS CLASS D',
#        'DRUGS - POSS CLASS D - INTENT TO MFR DIST DISP', 'DRUGS - OTHER',
#        'ASSAULT - SIMPLE', 'DRUGS - POSS CLASS C',
#        'DRUGS - SICK ASSIST - OTHER NARCOTIC',
#        'DRUGS - POSS CLASS C - INTENT TO MFR DIST DISP', 'STALKING',
#        'PROPERTY - MISSING', 'DRUGS - SICK ASSIST - HEROIN', 'GRAFFITI',
#        'DRUGS - SICK ASSIST - OTHER HARMFUL DRUG', 'DRUGS - POSS CLASS E',
#        'DRUGS - POSS CLASS E - INTENT TO MFR DIST DISP',
#        'DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS',
#        'DRUGS - CONSP TO VIOL CONTROLLED SUBSTANCE', 'DRUGS - POSSESSION',
#        'CONSPIRACY EXCEPT DRUG LAW',
#        'DRUGS - CLASS A TRAFFICKING OVER 18 GRAMS',
#        'DRUGS - POSSESSION OF DRUG PARAPHANALIA',
#        'DRUGS - CLASS D TRAFFICKING OVER 50 GRAMS'], dtype=object)

# %%
data['MONTH'].unique()
# Out:
# array([ 7,  6,  4,  5,  2,  3,  9, 10,  1, 11,  8, 12])

# %%
data['DISTRICT'].unique()
# Out:
# array(['B3', 'C6', 'D14', 'E13', nan, 'B2', 'E5', 'D4', 'C11', 'A1',
#        'E18', 'A7', 'A15'], dtype=object)

# %% [markdown]
# # ЗАДАЧА

# %%
# data = data.drop('capital-gain', axis = 1)\
#             .drop('capital-loss', axis = 1)\
#            .drop('education',    axis = 1)\
#            .drop('native-country', axis = 1).drop('fnlwgt', axis = 1)

# %%
data.count(axis=0)
# Out:
# INCIDENT_NUMBER        13497
# OFFENSE_CODE           13497
# OFFENSE_CODE_GROUP     13497
# OFFENSE_DESCRIPTION    13497
# DISTRICT               13403
# REPORTING_AREA         13497
# SHOOTING                   4
# OCCURRED_ON_DATE       13497
# YEAR                   13497
# MONTH                  13497
# DAY_OF_WEEK            13497
# HOUR                   13497
# UCR_PART               13497
# STREET                 13312
# Lat                    12836
# Long                   12836
# Location               13497
# dtype: int64

# %% [markdown]
# Мы можем видеть, что столбец, описывающий наличие выстрелов почти не заполнен

# %%
data = data.drop('SHOOTING', axis = 1)

# %%
data = data.drop('Location', axis = 1)

# %%
data = data.drop('Long', axis = 1)

# %%
data = data.drop('Lat', axis = 1)

# %%
data = data.drop('UCR_PART', axis = 1)

# %%
data
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 
RUGS - POSS CLASS B - INTENT TO MFR DIST DISP      NaN
# 19               DRUGS - POSS CLASS B - COCAINE, ETC.      NaN
# 22                                 INVESTIGATE PERSON       E5            559
# 27                                          VANDALISM       B2            312
# 28                                     VERBAL DISPUTE       D4            158
# 33                                     VERBAL DISPUTE       C6            231
# 35                                 INVESTIGATE PERSON      C11            823
# 36                           ASSAULT SIMPLE - BATTERY       B3            421
# 37                           ASSAULT SIMPLE - BATTERY       D4            138
# 38                                 INVESTIGATE PERSON       D4            273
# 40                                 INVESTIGATE PERSON       D4            903
# 42                                 INVESTIGATE PERSON       A1            111
# 49                                 INVESTIGATE PERSON       E5            563
# 50               DRUGS - POSS CLASS A - HEROIN, ETC.        C6            175
# 52     DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       C6            177
# 53     DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       C6            177
# 55                                TOWED MOTOR VEHICLE       D4            149
# 58                                 INVESTIGATE PERSON       B2            257
# 60                                 INVESTIGATE PERSON       B3            406
# 62                           ASSAULT SIMPLE - BATTERY       B3            458
# 64                                     VERBAL DISPUTE       D4            903
# 70                           ASSAULT SIMPLE - BATTERY       D4            632
# ...                                               ...      ...            ...
# 41246                                 PROPERTY - LOST      A15
# 41247                              INVESTIGATE PERSON      E18            957
# 41248       DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS      C11
# 41251            DRUGS - POSS CLASS B - COCAINE, ETC.       B3            413
# 41252                                  VERBAL DISPUTE       B3            416
# 41255                                       VANDALISM      C11            337
# 41256                                  VERBAL DISPUTE      C11            337
# 41262                              INVESTIGATE PERSON      D14            799
# 41265                                       VANDALISM       C6            231
# 41266                                  VERBAL DISPUTE       A7            902
# 41273  DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       C6            200
# 41274                                 PROPERTY - LOST       A1             78
# 41275                              INVESTIGATE PERSON       D4            903
# 41283                                 PROPERTY - LOST       B3            409
# 41290                                 PROPERTY - LOST       A1            111
# 41291                        ASSAULT SIMPLE - BATTERY       C6            194
# 41292                              INVESTIGATE PERSON       E5            694
# 41294                                  VERBAL DISPUTE       B3            418
# 41304                                 PROPERTY - LOST       A7             10
# 41309                                  VERBAL DISPUTE       C6            936
# 41312  DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP      C11            402
# 41313                              INVESTIGATE PERSON      C11            402
# 41316                                  VERBAL DISPUTE      E18            478
# 41318                        ASSAULT SIMPLE - BATTERY       A1             81
# 41320                                       VANDALISM       A7             16
# 41321                            DRUGS - POSS CLASS D      E13            573
# 41329                                 PROPERTY - LOST       A1            100
# 41333                                 PROPERTY - LOST       C6            177
# 41334                              INVESTIGATE PERSON       B2            300
# 41336            DRUGS - POSS CLASS B - COCAINE, ETC.      C11            341
#
#           OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR             STREET
# 0      2018-07-10 20:57:00  2018      7     Tuesday    20      BLUE HILL AVE
# 4      2018-07-10 20:11:00  2018      7     Tuesday    20         W THIRD ST
# 5      2018-07-10 21:08:00  2018      7     Tuesday    21        ALLSTATE RD
# 7      2018-07-10 20:17:00  2018      7     Tuesday    20        CHISWICK RD
# 8      2018-07-10 20:06:00  2018      7     Tuesday    20      WASHINGTON ST
# 14     2018-07-10 20:00:00  2018      7     Tuesday    20           ATLANTIC
# 15     2018-07-10 19:34:00  2018      7     Tuesday    19          SONOMA ST
# 17     2018-07-10 19:40:00  2018      7     Tuesday    19                NaN
# 18     2018-07-10 19:40:00  2018      7     Tuesday    19                NaN
# 19     2018-07-10 19:40:00  2018      7     Tuesday    19                NaN
# 41304  2017-11-29 19:30:00  2017     11   Wednesday    19        SARATOGA ST
# 41309  2018-02-07 13:11:00  2018      2   Wednesday    13       W SEVENTH ST
# 41312  2018-02-07 14:13:00  2018      2   Wednesday    14        ROCKWELL ST
# 41313  2018-02-07 14:13:00  2018      2   Wednesday    14        ROCKWELL ST
# 41316  2018-02-07 13:07:00  2018      2   Wednesday    13      RUSKINDALE RD
# 41318  2018-02-07 12:00:00  2018      2   Wednesday    12    MICHELANGELO ST
# 41320  2018-02-07 12:00:00  2018      2   Wednesday    12          FALCON ST
# 41321  2018-02-06 12:50:00  2018      2     Tuesday    12         MCBRIDE ST
# 41329  2018-02-03 23:00:00  2018      2    Saturday    23           BROAD ST
# 41333  2018-01-15 00:00:00  2018      1      Monday     0  MASSACHUSETTS AVE
# 41334  2017-03-01 00:00:00  2017      3   Wednesday     0        HIGHLAND ST
# 41336  2018-02-07 11:36:00  2018      2   Wednesday    11         BOWDOIN ST
#
# [13497 rows x 12 columns]

# %% [markdown]
# # Готовим данные

# %%
data['DISTRICT'].dtype.name
# Out:
# 'object'

# %%
data['OFFENSE_CODE'].dtype.name
# Out:
# 'int64'

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['INCIDENT_NUMBER', 'OFFENSE_CODE_GROUP', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'DAY_OF_WEEK', 'STREET']
# ['OFFENSE_CODE', 'YEAR', 'MONTH', 'HOUR']

# %%
for c in categorical_columns:
    print(c, data[c].unique())
# Out:
# INCIDENT_NUMBER ['I182054381' 'I182054374' 'I182054372' ... 'I182010033' 'I182010032'
#  'I182010030']
# OFFENSE_CODE_GROUP ['Verbal Disputes' 'Towed' 'Property Lost' 'Investigate Person'
#  'Vandalism' 'Drug Violation' 'Simple Assault']
# OFFENSE_DESCRIPTION ['VERBAL DISPUTE' 'TOWED MOTOR VEHICLE' 'PROPERTY - LOST'
#  'INVESTIGATE PERSON' 'VANDALISM' 'DRUGS - SALE / MANUFACTURING'
#  'DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP'
#  'DRUGS - POSS CLASS B - COCAINE, ETC.' 'ASSAULT SIMPLE - BATTERY'
#  'DRUGS - POSS CLASS A - HEROIN, ETC. '
#  'DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP' 'DRUGS - POSS CLASS D'
#  'DRUGS - POSS CLASS D - INTENT TO MFR DIST DISP' 'DRUGS - OTHER'
#  'ASSAULT - SIMPLE' 'DRUGS - POSS CLASS C'
#  'DRUGS - SICK ASSIST - OTHER NARCOTIC'
#  'DRUGS - POSS CLASS C - INTENT TO MFR DIST DISP' 'STALKING'
#  'PROPERTY - MISSING' 'DRUGS - SICK ASSIST - HEROIN' 'GRAFFITI'
#  'DRUGS - SICK ASSIST - OTHER HARMFUL DRUG' 'DRUGS - POSS CLASS E'
#  'DRUGS - POSS CLASS E - INTENT TO MFR DIST DISP'
#  'DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS'
#  'DRUGS - CONSP TO VIOL CONTROLLED SUBSTANCE' 'DRUGS - POSSESSION'
#  'CONSPIRACY EXCEPT DRUG LAW' 'DRUGS - CLASS A TRAFFICKING OVER 18 GRAMS'
#  'DRUGS - POSSESSION OF DRUG PARAPHANALIA'
#  'DRUGS - CLASS D TRAFFICKING OVER 50 GRAMS']
# DISTRICT ['B3' 'C6' 'D14' 'E13' nan 'B2' 'E5' 'D4' 'C11' 'A1' 'E18' 'A7' 'A15']
# REPORTING_AREA ['428' '211' '186' '788' '571' ' ' '319' '559' '312' '158' '231' '823'
#  '421' '138' '273' '903' '111' '563' '175' '177' '149' '257' '406' '458'
#  '632' '184' '778' '351' '294' '114' '765' '567' '393' '168' '494' '214'
#  '94' '179' '282' '486' '329' '418' '263' '332' '103' '344' '97' '727'
#  '389' '311' '338' '597' '325' '307' '817' '619' '315' '455' '200' '296'
#  '265' '345' '306' '298' '16' '578' '914' '326' '900' '105' '117' '917'
#  '427' '791' '562' '343' '336' '330' '463' '657' '112' '359' '75' '340'
#  '331' '551' '401' '355' '939' '289' '237' '466' '27' '488' '356' '60'
#  '92' '286' '522' '539' '787' '24' '287' '620' '12' '278' '178' '172'
#  '905' '335' '264' '608' '577' '624' '161' '248' '254' '582' '515' '55'
#  '464' '354' '165' '502' '634' '601' '487' '151' '183' '792' '692' '606'
#  '822' '906' '545' '441' '321' '793' '227' '735' '358' '583' '814' '166'
#  '774' '433' '285' '28' '77' '262' '258' '915' '364' '434' '496' '216'
#  '638' '26' '512' '115' '81' '206' '519' '429' '207' '243' '445' '162'
#  '304' '901' '500' '93' '193' '444' '755' '17' '170' '758' '469' '134'
#  '118' '648' '301' '68' '641' '919' '908' '461' '588' '349' '150' '171'
#  '101' '742' '680' '328' '388' '10' '29' '936' '89' '70' '403' '123' '446'
#  '308' '546' '807' '126' '780' '318' '794' '397' '498' '482' '462' '334'
#  '942' '623' '173' '457' '493' '130' '322' '288' '402' '305' '465' '796'
#  '715' '143' '348' '911' '572' '1' '256' '501' '320' '430' '360' '479'
#  '220' '517' '627' '133' '459' '271' '521' '144' '436' '33' '147' '270'
#  '668' '25' '108' '153' '435' '366' '783' '789' '565' '426' '303' '244'
#  '564' '423' '242' '431' '34' '943' '155' '416' '261' '591' '347' '549'
#  '438' '913' '228' '910' '283' '636' '74' '23' '912' '784' '164' '376'
#  '478' '409' '36' '691' '490' '626' '109' '449' '250' '194' '146' '804'
#  '476' '815' '420' '316' '602' '259' '574' '560' '605' '187' '468' '224'
#  '225' '456' '945' '598' '714' '614' '337' '941' '474' '125' '267' '450'
#  '443' '618' '235' '805' '442' '948' '313' '201' '309' '181' '944' '357'
#  '276' '561' '324' '192' '541' '61' '323' '503' '58' '552' '480' '398'
#  '768' '542' '550' '824' '640' '425' '226' '119' '432' '116' '520' '241'
#  '933' '387' '145' '811' '249' '280' '533' '66' '570' '754' '454' '240'
#  '573' '88' '408' '121' '217' '555' '137' '213' '291' '352' '380' '292'
#  '677' '630' '297' '530' '41' '946' '252' '621' '810' '80' '576' '622'
#  '410' '760' '801' '44' '405' '255' '930' '481' '3' '15' '79' '806' '32'
#  '95' '163' '57' '157' '752' '281' '499' '470' '748' '327' '122' '544'
#  '777' '612' '189' '525' '43' '527' '513' '131' '575' '188' '697' '579'
#  '604' '128' '644' '581' '142' '798' '797' '295' '649' '772' '613' '239'
#  '472' '180' '726' '160' '484' '135' '540' '185' '106' '647' '566' '625'
#  '154' '907' '113' '2' '84' '215' '176' '317' '422' '396' '439' '53' '30'
#  '197' '260' '534' '350' '363' '770' '782' '453' '531' '50' '938' '516'
#  '723' '63' '341' '495' '45' '712' '594' '485' '14' '681' '54' '367' '553'
#  '272' '203' '799' '961' '136' '19' '556' '219' '773' '803' '247' '664'
#  '120' '940' '802' '693' '749' '412' '523' '959' '497' '167' '633' '483'
#  '676' '69' '38' '812' '958' '587' '721' '102' '962' '377' '610' '37'
#  '759' '729' '448' '407' '733' '510' '411' '274' '776' '22' '417' '233'
#  '509' '293' '548' '467' '159' '719' '711' '390' '67' '132' '460' '732'
#  '56' '368' '709' '230' '717' '385' '771' '781' '413' '419' '790' '156'
#  '660' '795' '764' '35' '532' '617' '916' '756' '238' '129' '140' '342'
#  '558' '268' '526' '694' '392' '223' '245' '300' '141' '266' '611' '87'
#  '404' '362' '785' '775' '31' '437' '277' '628' '492' '607' '769' '584'
#  '83' '529' '451' '152' '747' '921' '20' '90' '800' '234' '440' '8' '127'
#  '447' '511' '679' '819' '222' '745' '384' '508' '381' '918' '107' '710'
#  '603' '378' '373' '399' '365' '593' '635' '475' '275' '269' '821' '629'
#  '76' '904' '290' '538' '706' '279' '91' '221' '725' '670' '394' '361'
#  '722' '195' '786' '375' '569' '7' '11' '299' '73' '124' '202' '71' '473'
#  '9' '536' '543' '704' '808' '246' '902' '678' '236' '374' '645' '489'
#  '64' '391' '110' '547' '86' '210' '696' '750' '169' '174' '6' '42' '652'
#  '104' '757' '232' '139' '85' '209' '643' '557' '506' '767' '302' '761'
#  '730' '39' '452' '21' '284' '59' '779' '716' '383' '78' '713' '683' '518'
#  '653' '379' '400' '395' '100' '98' '937' '182' '642' '809' '703' '724'
#  '415' '609' '333' '314' '65' '639' '631' '686' '707' '616' '229' '72'
#  '196' '310' '590' '954' '763' '346' '637' '926' '212' '925' '924' '47'
#  '40' '535' '372' '952' '751' '731' '528' '62' '615' '82' '650' '13' '687'
#  '339' '585' '651' '370' '554' '909' '507' '253' '667' '957' '524' '923'
#  '586' '734' '537' '720' '199' '702' '932' '353' '816' '414' '204' '695'
#  '656' '744' '424' '46' '956' '655' '820' '205' '596' '654' '96' '18'
#  '766' '685' '386' '737' '514' '491' '920' '504' '935' '746' '701' '369'
#  '762' '52' '953' '191' '672' '208' '743' '922' '951' '675' '741' '753'
#  '688' '949' '568' '589' '4' '700' '663' '736' '669' '818' '718' '674']
# OCCURRED_ON_DATE ['2018-07-10 20:57:00' '2018-07-10 20:11:00' '2018-07-10 21:08:00' ...
#  '2018-02-03 23:00:00' '2018-01-15 00:00:00' '2017-03-01 00:00:00']
# DAY_OF_WEEK ['Tuesday' 'Monday' 'Saturday' 'Thursday' 'Sunday' 'Friday' 'Wednesday']
# STREET ['BLUE HILL AVE' 'W THIRD ST' 'ALLSTATE RD' ... 'IMRIE RD' 'HARTFORD ST'
#  'FLETCHER ST']

# %%
print(categorical_columns)
# Out:
# ['INCIDENT_NUMBER', 'OFFENSE_CODE_GROUP', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'DAY_OF_WEEK', 'STREET']

# %% [markdown]
# # Обрабатываем пропущенные значения

# %% [markdown]
# Если данные содержат пропущенные значения, то имеется две простые альтернативы:
#
# удалить столбцы с такими значениями (data = data.dropna(axis = 1)),
# удалить строки с такими значениями (data = data.dropna(axis = 0)).
# После этого данных может стать совсем мало.
#
# Куда более эффективным (и в то же время по-прежнему простым) методом обычно является заполнение пропущенных значений для каждой количественной переменной их средним или медианным значением. Для категориальных признаков пропущенные значения можно заполнить самым популярным значением в столбце.

# %%
data.median(axis = 0)
# Out:
# OFFENSE_CODE    3115.0
# YEAR            2018.0
# MONTH              4.0
# HOUR              14.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# OFFENSE_CODE    13497
# YEAR            13497
# MONTH           13497
# HOUR            13497
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# INCIDENT_NUMBER        13497
# OFFENSE_CODE_GROUP     13497
# OFFENSE_DESCRIPTION    13497
# DISTRICT               13403
# REPORTING_AREA         13497
# OCCURRED_ON_DATE       13497
# DAY_OF_WEEK            13497
# STREET                 13312
# dtype: int64

# %% [markdown]
# Удаляем столбцы, в которых есть незаполненные значения

# %% [markdown]
# Необходимо переобозначить категориальные столбцы

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']

# %%
data[categorical_columns].count(axis = 0)
# Out:
# INCIDENT_NUMBER        13497
# OFFENSE_CODE_GROUP     13497
# OFFENSE_DESCRIPTION    13497
# DISTRICT               13403
# REPORTING_AREA         13497
# OCCURRED_ON_DATE       13497
# DAY_OF_WEEK            13497
# STREET                 13312
# dtype: int64

# %%
data[numerical_columns].count(axis = 0)
# Out:
# OFFENSE_CODE    13497
# YEAR            13497
# MONTH           13497
# HOUR            13497
# dtype: int64

# %%
data['INCIDENT_NUMBER'].describe()
# Out:
# count          13497
# unique         12845
# top       I182051950
# freq               5
# Name: INCIDENT_NUMBER, dtype: object

# %%
type(data['INCIDENT_NUMBER'].describe())
# Out:
# pandas.core.series.Series

# %%
data['INCIDENT_NUMBER'].describe().top
# Out:
# 'I182051950'

# %%
data['INCIDENT_NUMBER'] = data['INCIDENT_NUMBER'].fillna('I162030584')

# %%
data.describe(include = [object])
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION DISTRICT  \
# count            13497               13497               13497    13403
# unique           12845                   7                  32       12
# top         I182051950  Investigate Person  INVESTIGATE PERSON       B2
# freq                 5                2436                2436     2056
#
#        REPORTING_AREA     OCCURRED_ON_DATE DAY_OF_WEEK         STREET
# count           13497                13497       13497          13312
# unique            837                11958           7           2030
# top                    2018-01-01 00:00:00      Friday  WASHINGTON ST
# freq              743                    8        2059            626

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        INCIDENT_NUMBER  OFFENSE_CODE_GROUP OFFENSE_DESCRIPTION DISTRICT  \
# count            13497               13497               13497    13497
# unique           12845                   7                  32       12
# top         I182051950  Investigate Person  INVESTIGATE PERSON       B2
# freq                 5                2436                2436     2150
#
#        REPORTING_AREA     OCCURRED_ON_DATE DAY_OF_WEEK         STREET
# count           13497                13497       13497          13497
# unique            837                11958           7           2030
# top                    2018-01-01 00:00:00      Friday  WASHINGTON ST
# freq              743                    8        2059            811

# %% [markdown]
# # Векторизация

# %% [markdown]
# Необходимо что-то предпринять по отношению к категориальным столбцам

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# [] ['INCIDENT_NUMBER', 'OFFENSE_CODE_GROUP', 'OFFENSE_DESCRIPTION', 'DISTRICT', 'REPORTING_AREA', 'OCCURRED_ON_DATE', 'DAY_OF_WEEK', 'STREET']

# %% [markdown]
# К небинарными признакам применим метод векторизации, который заключается в следующем.
#
# Признак j, принимающий s значений, заменим на s признаков, принимащих значения 0 или 1, в зависимости от того, чему равно значение исходного признака j.
#
# Например, в нашей задаче признак DayOfWeek принимает 7 различных значений:

# %%
data['DAY_OF_WEEK'].unique()
# Out:
# array(['Tuesday', 'Monday', 'Saturday', 'Thursday', 'Sunday', 'Friday',
#        'Wednesday'], dtype=object)

# %%
data['DISTRICT'].unique()
# Out:
# array(['B3', 'C6', 'D14', 'E13', 'B2', 'E5', 'D4', 'C11', 'A1', 'E18',
#        'A7', 'A15'], dtype=object)

# %%
data_nonbinary = pd.get_dummies(data[['DISTRICT', 'REPORTING_AREA', 'STREET',
                                      'DAY_OF_WEEK']])
print(data_nonbinary.columns)
# Out:
# Index(['DISTRICT_A1', 'DISTRICT_A15', 'DISTRICT_A7', 'DISTRICT_B2',
#        'DISTRICT_B3', 'DISTRICT_C11', 'DISTRICT_C6', 'DISTRICT_D14',
#        'DISTRICT_D4', 'DISTRICT_E13',
#        ...
#        'STREET_YAWKEY WAY', 'STREET_YORK ST', 'STREET_ZEIGLER ST',
#        'DAY_OF_WEEK_Friday', 'DAY_OF_WEEK_Monday', 'DAY_OF_WEEK_Saturday',
#        'DAY_OF_WEEK_Sunday', 'DAY_OF_WEEK_Thursday', 'DAY_OF_WEEK_Tuesday',
#        'DAY_OF_WEEK_Wednesday'],
#       dtype='object', length=2886)

# %% [markdown]
# # Нормализация количественных признаков

# %% [markdown]
# Многие алгоритмы машинного обучения чувствительны к масштабированию данных. К таким алгоритмам, например, относится метод ближайших соседей, машина опорных векторов и др.
#
# В этом случае количественные признаки полезно нормализовать. Это можно делать разными способами. Например, каждый количественный признак приведем к нулевому среднему и единичному среднеквадратичному отклонению:

# %%
data_numerical = data[numerical_columns]

# %%
data_numerical.describe()
# Out:
#        OFFENSE_CODE          YEAR         MONTH          HOUR
# count  13497.000000  13497.000000  13497.000000  13497.000000
# mean    2389.703267   2017.993702      4.407128     13.181077
# std     1003.015530      0.085416      1.550184      6.258755
# min      801.000000   2015.000000      1.000000      0.000000
# 25%     1402.000000   2018.000000      3.000000      9.000000
# 50%     3115.000000   2018.000000      4.000000     14.000000
# 75%     3301.000000   2018.000000      6.000000     18.000000
# max     3410.000000   2018.000000     12.000000     23.000000

# %%
data_numerical = data_numerical.drop('OFFENSE_CODE', axis = 1)

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#                YEAR         MONTH          HOUR
# count  1.349700e+04  1.349700e+04  1.349700e+04
# mean   2.473756e-13 -3.103107e-14 -2.402275e-16
# std    1.000000e+00  1.000000e+00  1.000000e+00
# min   -3.504862e+01 -2.197886e+00 -2.106022e+00
# 25%    7.372995e-02 -9.077165e-01 -6.680366e-01
# 50%    7.372995e-02 -2.626317e-01  1.308444e-01
# 75%    7.372995e-02  1.027538e+00  7.699491e-01
# max    7.372995e-02  4.898046e+00  1.568830e+00

# %% [markdown]
# # Соединяем всё в одну таблицу

# %%
data
# Out:
#       INCIDENT_NUMBER  OFFENSE_CODE  OFFENSE_CODE_GROUP  \
# 0          I182054381          3301     Verbal Disputes
# 4          I182054374          3410               Towed
# 5          I182054372          3201       Property Lost
# 7          I182054369          3115  Investigate Person
# 8          I182054368          3115  Investigate Person
# 14         I182054360          3115  Investigate Person
# 15         I182054358          1402           Vandalism
# 17         I182054356          1810      Drug Violation
# 18         I182054356          1843      Drug Violation
# 19         I182054356          1849      Drug Violation
# 22         I182054352          3115  Investigate Person
# 27         I182054346          1402           Vandalism
# 28         I182054345          3301     Verbal Disputes
# 33         I182054337          3301     Verbal Disputes
# 35         I182054334          3115  Investigate Person
# 36         I182054333           802      Simple Assault
# 37         I182054331           802      Simple Assault
# 38         I182054330          3115  Investigate Person
# 40         I182054328          3115  Investigate Person
# 42         I182054326          3115  Investigate Person
# 49         I182054317          3115  Investigate Person
# 50         I182054316          1842      Drug Violation
# 52         I182054314          1841      Drug Violation
# 53         I182054314          1843      Drug Violation
# 55         I182054312          3410               Towed
# 58         I182054308          3115  Investigate Person
# 60         I182054306          3115  Investigate Person
# 62         I182054304           802      Simple Assault
# 64         I182054302          3301     Verbal Disputes
# 70         I182054296           802      Simple Assault
# ...               ...           ...                 ...
# 41246      I182010137          3201       Property Lost
# 41247      I182010135          3115  Investigate Person
# 41248      I182010132          1806      Drug Violation
# 41251      I182010128          1849      Drug Violation
# 41252      I182010127          3301     Verbal Disputes
# 41255      I182010123          1402           Vandalism
# 41256      I182010123          3301     Verbal Disputes
# 41262      I182010116          3115  Investigate Person
# 41265      I182010113          1402           Vandalism
# 41266      I182010112          3301     Verbal Disputes
# 41273      I182010103          1841      Drug Violation
# 41274      I182010102          3201       Property Lost
# 41275      I182010101          3115  Investigate Person
# 41283      I182010091          3201       Property Lost
# 41290      I182010082          3201       Property Lost
# 41291      I182010081           802      Simple Assault
# 41292      I182010080          3115  Investigate Person
# 41294      I182010077          3301     Verbal Disputes
# 41304      I182010068          3201       Property Lost
# 41309      I182010062          3301     Verbal Disputes
# 41312      I182010058          1841      Drug Violation
# 41313      I182010058          3115  Investigate Person
# 41316      I182010055          3301     Verbal Disputes
# 41318      I182010053           802      Simple Assault
# 41320      I182010048          1402           Vandalism
# 41321      I182010047          1845      Drug Violation
# 41329      I182010039          3201       Property Lost
# 41333      I182010033          3201       Property Lost
# 41334      I182010032          3115  Investigate Person
# 41336      I182010030          1849      Drug Violation
#
#                                   OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA  \
# 0                                      VERBAL DISPUTE       B3            428
# 4                                 TOWED MOTOR VEHICLE       C6            211
# 5                                     PROPERTY - LOST       C6            186
# 7                                  INVESTIGATE PERSON      D14            788
# 8                                  INVESTIGATE PERSON      E13            571
# 14                                 INVESTIGATE PERSON       B2
# 15                                          VANDALISM       B2            319
# 17                       DRUGS - SALE / MANUFACTURING       B2
# 18     DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       B2
# 19               DRUGS - POSS CLASS B - COCAINE, ETC.       B2
# 22                                 INVESTIGATE PERSON       E5            559
# 27                                          VANDALISM       B2            312
# 28                                     VERBAL DISPUTE       D4            158
# 33                                     VERBAL DISPUTE       C6            231
# 35                                 INVESTIGATE PERSON      C11            823
# 36                           ASSAULT SIMPLE - BATTERY       B3            421
# 37                           ASSAULT SIMPLE - BATTERY       D4            138
# 38                                 INVESTIGATE PERSON       D4            273
# 40                                 INVESTIGATE PERSON       D4            903
# 42                                 INVESTIGATE PERSON       A1            111
# 49                                 INVESTIGATE PERSON       E5            563
# 50               DRUGS - POSS CLASS A - HEROIN, ETC.        C6            175
# 52     DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       C6            177
# 53     DRUGS - POSS CLASS B - INTENT TO MFR DIST DISP       C6            177
# 55                                TOWED MOTOR VEHICLE       D4            149
# 58                                 INVESTIGATE PERSON       B2            257
# 60                                 INVESTIGATE PERSON       B3            406
# 62                           ASSAULT SIMPLE - BATTERY       B3            458
# 64                                     VERBAL DISPUTE       D4            903
# 70                           ASSAULT SIMPLE - BATTERY       D4            632
# ...                                               ...      ...            ...
# 41246                                 PROPERTY - LOST      A15
# 41247                              INVESTIGATE PERSON      E18            957
# 41248       DRUGS - CLASS B TRAFFICKING OVER 18 GRAMS      C11
# 41251            DRUGS - POSS CLASS B - COCAINE, ETC.       B3            413
# 41252                                  VERBAL DISPUTE       B3            416
# 41255                                       VANDALISM      C11            337
# 41256                                  VERBAL DISPUTE      C11            337
# 41262                              INVESTIGATE PERSON      D14            799
# 41265                                       VANDALISM       C6            231
# 41266                                  VERBAL DISPUTE       A7            902
# 41273  DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP       C6            200
# 41274                                 PROPERTY - LOST       A1             78
# 41275                              INVESTIGATE PERSON       D4            903
# 41283                                 PROPERTY - LOST       B3            409
# 41290                                 PROPERTY - LOST       A1            111
# 41291                        ASSAULT SIMPLE - BATTERY       C6            194
# 41292                              INVESTIGATE PERSON       E5            694
# 41294                                  VERBAL DISPUTE       B3            418
# 41304                                 PROPERTY - LOST       A7             10
# 41309                                  VERBAL DISPUTE       C6            936
# 41312  DRUGS - POSS CLASS A - INTENT TO MFR DIST DISP      C11            402
# 41313                              INVESTIGATE PERSON      C11            402
# 41316                                  VERBAL DISPUTE      E18            478
# 41318                        ASSAULT SIMPLE - BATTERY       A1             81
# 41320                                       VANDALISM       A7             16
# 41321                            DRUGS - POSS CLASS D      E13            573
# 41329                                 PROPERTY - LOST       A1            100
# 41333                                 PROPERTY - LOST       C6            177
# 41334                              INVESTIGATE PERSON       B2            300
# 41336            DRUGS - POSS CLASS B - COCAINE, ETC.      C11            341
#
#           OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOU
# 41273  2018-02-07 17:24:00  2018      2   Wednesday    17         W BROADWAY
# 41274  2017-11-10 00:00:00  2017     11      Friday     0           UNION ST
# 41275  2018-02-07 16:52:00  2018      2   Wednesday    16         TREMONT ST
# 41283  2018-02-05 16:00:00  2018      2      Monday    16           RIVER ST
# 41290  2018-02-02 05:30:00  2018      2      Friday     5           AVERY ST
# 41291  2018-02-07 15:11:00  2018      2   Wednesday    15     DORCHESTER AVE
# 41292  2018-02-07 14:20:00  2018      2   Wednesday    14            WELD ST
# 41294  2018-02-07 14:08:00  2018      2   Wednesday    14          FULLER ST
# 41304  2017-11-29 19:30:00  2017     11   Wednesday    19        SARATOGA ST
# 41309  2018-02-07 13:11:00  2018      2   Wednesday    13       W SEVENTH ST
# 41312  2018-02-07 14:13:00  2018      2   Wednesday    14        ROCKWELL ST
# 41313  2018-02-07 14:13:00  2018      2   Wednesday    14        ROCKWELL ST
# 41316  2018-02-07 13:07:00  2018      2   Wednesday    13      RUSKINDALE RD
# 41318  2018-02-07 12:00:00  2018      2   Wednesday    12    MICHELANGELO ST
# 41320  2018-02-07 12:00:00  2018      2   Wednesday    12          FALCON ST
# 41321  2018-02-06 12:50:00  2018      2     Tuesday    12         MCBRIDE ST
# 41329  2018-02-03 23:00:00  2018      2    Saturday    23           BROAD ST
# 41333  2018-01-15 00:00:00  2018      1      Monday     0  MASSACHUSETTS AVE
# 41334  2017-03-01 00:00:00  2017      3   Wednesday     0        HIGHLAND ST
# 41336  2018-02-07 11:36:00  2018      2   Wednesday    11         BOWDOIN ST
#
# [13497 rows x 12 columns]

# %%
data.median(axis = 0)
# Out:
# OFFENSE_CODE    3115.0
# YEAR            2018.0
# MONTH              4.0
# HOUR              14.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data.count(axis = 0)
# Out:
# INCIDENT_NUMBER        13497
# OFFENSE_CODE           13497
# OFFENSE_CODE_GROUP     13497
# OFFENSE_DESCRIPTION    13497
# DISTRICT               13497
# REPORTING_AREA         13497
# OCCURRED_ON_DATE       13497
# YEAR                   13497
# MONTH                  13497
# DAY_OF_WEEK            13497
# HOUR                   13497
# STREET                 13497
# dtype: int64

# %%
y = data['OFFENSE_CODE_GROUP']

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (13497, 2889)

# %%
data.describe()
# Out:
#                YEAR         MONTH          HOUR   DISTRICT_A1  DISTRICT_A15  \
# count  1.349700e+04  1.349700e+04  1.349700e+04  13497.000000  13497.000000
# mean   2.473756e-13 -3.103107e-14 -2.402275e-16      0.104171      0.020449
# std    1.000000e+00  1.000000e+00  1.000000e+00      0.305494      0.141536
# min   -3.504862e+01 -2.197886e+00 -2.106022e+00      0.000000      0.000000
# 25%    7.372995e-02 -9.077165e-01 -6.680366e-01      0.000000      0.000000
# 50%    7.372995e-02 -2.626317e-01  1.308444e-01      0.000000      0.000000
# 75%    7.372995e-02  1.027538e+00  7.699491e-01      0.000000      0.000000
# max    7.372995e-02  4.898046e+00  1.568830e+00      1.000000      1.000000
#
#         DISTRICT_A7   DISTRICT_B2   DISTRICT_B3  DISTRICT_C11   DISTRICT_C6  \
# count  13497.000000  13497.000000  13497.000000  13497.000000  13497.000000
# mean       0.041787      0.159295      0.129140      0.128992      0.080907
# std        0.200110      0.365964      0.335367      0.335203      0.272702
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                ...            STREET_YAWKEY WAY  STREET_YORK ST  \
# count          ...                 13497.000000    13497.000000
# mean           ...                     0.001334        0.000296
# std            ...                     0.036496        0.017213
# min            ...                     0.000000        0.000000
# 25%            ...                     0.000000        0.000000
# 50%            ...                     0.000000        0.000000
# 75%            ...                     0.000000        0.000000
# max            ...                     1.000000        1.000000
#
#        STREET_ZEIGLER ST  DAY_OF_WEEK_Friday  DAY_OF_WEEK_Monday  \
# count       13497.000000        13497.000000        13497.000000
# mean            0.000593            0.152552            0.139957
# std             0.024340            0.359569            0.346955
# min             0.000000            0.000000            0.000000
# 25%             0.000000            0.000000            0.000000
# 50%             0.000000            0.000000            0.000000
# 75%             0.000000            0.000000            0.000000
# max             1.000000            1.000000            1.000000
#
#        DAY_OF_WEEK_Saturday  DAY_OF_WEEK_Sunday  DAY_OF_WEEK_Thursday  \
# count          13497.000000        13497.000000          13497.000000
# mean               0.146255            0.123657              0.146107
# std                0.353374            0.329202              0.353226
# min                0.000000            0.000000              0.000000
# 25%                0.000000            0.000000              0.000000
# 50%                0.000000            0.000000              0.000000
# 75%                0.000000            0.000000              0.000000
# max                1.000000            1.000000              1.000000
#
#        DAY_OF_WEEK_Tuesday  DAY_OF_WEEK_Wednesday
# count         13497.000000           13497.000000
# mean              0.150922               0.140550
# std               0.357987               0.347569
# min               0.000000               0.000000
# 25%               0.000000               0.000000
# 50%               0.000000               0.000000
# 75%               0.000000               0.000000
# max               1.000000               1.000000
#
# [8 rows x 2889 columns]

# %% [markdown]
# # X и Y

# %%
# X = data.drop(('Category'), axis = 1) # выбрасываем столбец 'class' - в нашем случае уже все сделано
# y = data['Category']
X = data
feature_names = data.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
X.describe()
# Out:
#                YEAR         MONTH          HOUR   DISTRICT_A1  DISTRICT_A15  \
# count  1.349700e+04  1.349700e+04  1.349700e+04  13497.000000  13497.000000
# mean   2.473756e-13 -3.103107e-14 -2.402275e-16      0.104171      0.020449
# std    1.000000e+00  1.000000e+00  1.000000e+00      0.305494      0.141536
# min   -3.504862e+01 -2.197886e+00 -2.106022e+00      0.000000      0.000000
# 25%    7.372995e-02 -9.077165e-01 -6.680366e-01      0.000000      0.000000
# 50%    7.372995e-02 -2.626317e-01  1.308444e-01      0.000000      0.000000
# 75%    7.372995e-02  1.027538e+00  7.699491e-01      0.000000      0.000000
# max    7.372995e-02  4.898046e+00  1.568830e+00      1.000000      1.000000
#
#         DISTRICT_A7   DISTRICT_B2   DISTRICT_B3  DISTRICT_C11   DISTRICT_C6  \
# count  13497.000000  13497.000000  13497.000000  13497.000000  13497.000000
# mean       0.041787      0.159295      0.129140      0.128992      0.080907
# std        0.200110      0.365964      0.335367      0.335203      0.272702
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                ...            STREET_YAWKEY WAY  STREET_YORK ST  \
# count          ...                 13497.000000    13497.000000
# mean           ...                     0.001334        0.000296
# std            ...                     0.036496        0.017213
# min            ...                     0.000000        0.000000
# 25%            ...                     0.000000        0.000000
# 50%            ...                     0.000000        0.000000
# 75%            ...                     0.000000        0.000000
# max            ...                     1.000000        1.000000
#
#        STREET_ZEIGLER ST  DAY_OF_WEEK_Friday  DAY_OF_WEEK_Monday  \
# count       13497.000000        13497.000000        13497.000000
# mean            0.000593            0.152552            0.139957
# std             0.024340            0.359569            0.346955
# min             0.000000            0.000000            0.000000
# 25%             0.000000            0.000000            0.000000
# 50%             0.000000            0.000000            0.000000
# 75%             0.000000            0.000000            0.000000
# max             1.000000            1.000000            1.000000
#
#        DAY_OF_WEEK_Saturday  DAY_OF_WEEK_Sunday  DAY_OF_WEEK_Thursday  \
# count          13497.000000        13497.000000          13497.000000
# mean               0.146255            0.123657              0.146107
# std                0.353374            0.329202              0.353226
# min                0.000000            0.000000              0.000000
# 25%                0.000000            0.000000              0.000000
# 50%                0.000000            0.000000              0.000000
# 75%                0.000000            0.000000              0.000000
# max                1.000000            1.000000              1.000000
#
#        DAY_OF_WEEK_Tuesday  DAY_OF_WEEK_Wednesday
# count         13497.000000           13497.000000
# mean              0.150922               0.140550
# std               0.357987               0.347569
# min               0.000000               0.000000
# 25%               0.000000               0.000000
# 50%               0.000000               0.000000
# 75%               0.000000               0.000000
# max               1.000000               1.000000
#
# [8 rows x 2889 columns]

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (13497, 2889)
# (13497,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 9447 4050

# %% [markdown]
#  библиотеке scikit-learn реализована масса алгоритмов машинного обучения.
#
# Некоторые алгоритмы машинного обучения, реализованные в scikit-learn:
# Метод	Класс
# kNN – $k$ ближайших соседей	sklearn.neighbors.KNeighborsClassifier
# LDA – линейный дискриминантный анализ	sklearn.discriminant_analysis.LinearDiscriminantAnalysis
# QDA – квадратичный дискриминантный анализ	sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis
# Logistic – логистическая регрессия	sklearn.linear_model.LogisticRegression
# SVC – машина опорных векторов	sklearn.svm.SVC
# Tree – деревья решений	sklearn.tree.DecisionTreeClassifier
# RF – случайный лес	sklearn.ensemble.RandomForestClassifier
# ExtrRF – экстремально случайный лес
# AdaBoost – алгоритм AdaBoost	sklearn.ensemble.AdaBoostClassifier
# GBT – градиентный бустинг деревьев решений	sklearn.ensemble.GradientBoostingClassifier
# Нейронные сети
# Основные методы классов, реализующих алгоритмы машинного обучения
# Все алгоритмы выполнены в виде классов, обладающих по крайней мере следующими методами:
#
# Метод класса	Описание
# fit(X_train, y_train)	обучение (тренировка) модели на обучающей выборке X_train, y_train
# predict(X)	предсказание на данных X
# set_params(**params)	установка параметров алгоритма
# get_params()	чтение параметров алгоритма
# Заметим, что параметры алгоритмов обучения можно задавать как в конструкторе класса, так и с помощью метода set_params(**params).
#
# Таблица наличия/отсутствия методов для основных алгоритмов машинного обучения:
# Методы класса	kNN	LDA	QDA	Logistic	SVC	Tree	RF	AdaBoost	GBT
# fit(X, y)	+	+	+	+	+	+	+	+	+
# predict(X)	+	+	+	+	+	+	+	+	+
# predict_proba(X)	+	+	+	+		+	+	+	+
# predict_log_proba(X)		+	+	+		+	+	+	+
# score(X, y)	+	+	+	+	+	+	+	+	+
# decision_function(X)		+	+	+	+			+	+
# transform(X)		+		+		+	+		+
# staged_decision_function(X)								+	+
# staged_predict(X)								+	+
# staged_predict_proba(X)								+	+
# staged_score(X, y)								+	+
# set_params(**params)	+	+	+	+	+	+	+	+	+
# get_params()	+	+	+	+	+	+	+	+	+

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=1, n_neighbors=10, p=2,
#            weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.5749973536572457 0.7167901234567902

# %%
err_test = 1 - knn.score(X_test, y_test) # Другой способ

# %%
err_test
# Out:
# 0.7167901234567902

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[358  79  28  50  26  21  29]
#  [202 180  58 101  61  62  74]
#  [111 106  79  88  31  21  35]
#  [146 143  68 155  45  48  70]
#  [ 78  77  30  47 202  27  30]
#  [107 125  42  79  63  58  53]
#  [120 140  21  79  42  40 115]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]])

# %% [markdown]
# # Обучаем классификатор

# %%
from sklearn.neural_network import MLPClassifier

# %%
# TRY 1 LAYER with 1 neuron
mlp_model = MLPClassifier(hidden_layer_sizes = (1,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(1,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
# after fitting the model we can try to check it's opportunities
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
print(
# error on the train set
    np.mean(y_train != y_train_pred),
# error on the test set
    np.mean(y_test != y_test_pred))
# Out:
# 0.67513496348047 0.7419753086419754

# %%
# the error on the test set is actually the same as in the train and the difference is really small.
print(np.mean(y_train != y_train_pred) - np.mean(y_test != y_test_pred))
# Out:
# -0.06684034516150539

# %%
# TRY 1 LAYER with 2 neurons
mlp_model = MLPClassifier(hidden_layer_sizes = (2,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(2,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
# after fitting the model we can try to check it's opportunities
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %%
print(
# error on the train set
    np.mean(y_train != y_train_pred),
# error on the test set
    np.mean(y_test != y_test_pred))
# Out:
# 0.5861119932253626 0.7224691358024692

# %%
# the error on the test set AGAIN is pretty the same. But we can see that the overall error become less due to second neuron
print(np.mean(y_train != y_train_pred) - np.mean(y_test != y_test_pred))
# Out:
# -0.13635714257710663

# %%
# Hyper parameter manual fitting for 100 neurons on 1 layer
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
# Draw a plots to detect hyper parameneter dependence
plt.plot(alpha_arr, train_err, 'b-o', label = 'test')
plt.plot(alpha_arr, test_err, 'r-o', label = 'train')
plt.xlim([np.min(alpha_arr), np.max(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass
# alpha is L2 regularization parameter which is used to fight against overfitting. Current plot shows us that making the
# parameter less is better for the ovefitting problem. The error on the test set is less than on the train set.
# But on on the large amount of the alpha we can notice some places where the error on the test set is higher which signals
# us about overfitting.

# %%
# A minimal error (during the hyper parameter fitting)
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.3565152958611199 0.6622222222222223

# %%
# Show an alpha which was the best from the point of "error" view
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [5.62341325]

# %%
# Final training on with optimal value on 2 NEURONS
alpha_opt = alpha_opt[0]
mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (100,),
                          solver = 'lbfgs', activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)

y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# Error rate
print(np.mean(y_train != y_train_pred))
print(np.mean(y_test != y_test_pred))
# Out:
# 0.47327193818143326
# 0.6622222222222223

# %%
# Let's try to find a dependence of model with DEFAULT alpha on the amount of NEURONS in the range
# from 1 to 100 with step 5 for 3 layers
layer_sizes = np.arange(1, 100, 5)
test_err = []
train_err = []
for size in layer_sizes:
    mlp_model = MLPClassifier(hidden_layer_sizes = (size, size, size, ), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
# Draw a plots to detect layers amount dependence
plt.plot(layer_sizes, train_err, 'b-o', label = 'test')
plt.plot(layer_sizes, test_err, 'r-o', label = 'train')
plt.xlim([np.min(layer_sizes), np.max(layer_sizes)])
plt.title('Error vs. layers')
plt.xlabel('layers')
plt.ylabel('error')
plt.legend()
pass
# we can see that increasing the amount of layers is making the model more complex and the error is less.
# but all this good stuff should be paid by the complexity and the time of the fitting.

# %%
print(X.shape)
print(y.shape)
# Out:
# (13497, 2889)
# (13497,)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20, random_state = 7)
N_test, _ = X_test.shape

# %%
from sklearn.neural_network import MLPClassifier
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#        beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#        hidden_layer_sizes=(100,), learning_rate='constant',
#        learning_rate_init=0.001, max_iter=200, momentum=0.9,
#        nesterovs_momentum=True, power_t=0.5, random_state=42, shuffle=True,
#        solver='lbfgs', tol=0.0001, validation_fraction=0.1, verbose=False,
#        warm_start=False)

# %%
X_test
# Out:
#           YEAR     MONTH      HOUR  DISTRICT_A1  DISTRICT_A15  DISTRICT_A7  \
# 6203   0.07373  1.027538  0.769949            1             0            0
# 6548   0.07373  1.027538  0.769949            0             0            0
# 29658  0.07373 -0.907717  0.450397            1             0            0
# 20339  0.07373 -0.262632  1.568830            0             0            1
# 33936  0.07373 -0.907717  0.130844            0             0            0
# 41191  0.07373 -1.552801 -1.786470            0             0            0
# 36861  0.07373 -1.552801 -0.028932            0             0            0
# 5249   0.07373  1.027538 -1.786470            1             0            0
# 20095  0.07373  0.382453  0.610173            0             0            0
# 29003  0.07373 -0.907717  1.568830            0             0            0
# 29922  0.07373 -0.907717  0.130844            0             0            0
# 18749  0.07373  0.382453 -1.307141            0             0            0
# 1403   0.07373  1.672623 -0.028932            0             0            0
# 31769  0.07373 -0.907717 -1.147365            1             0            0
# 19054  0.07373  0.382453 -1.946246            0             0            0
# 8176   0.07373  1.027538 -0.508260            0             0            0
# 12703  0.07373  0.382453  1.089502            0             0            0
# 20092  0.07373 -0.262632  0.929725            0             0            1
# 21077  0.07373 -0.262632 -0.188708            0             0            0
# 38072  0.07373 -1.552801  0.929725            0             0            0
# 27815  0.07373 -0.907717  0.450397            1             0            0
# 29912  0.07373 -0.907717  0.450397            0             0            0
# 26774  0.07373 -0.262632  0.130844            0             0            0
# 19254  0.07373  0.382453 -0.028932            0             0            0
# 35601  0.07373 -1.552801 -0.827813            0             0            0
# 24798  0.07373 -0.262632  0.929725            0             0            1
# 19444  0.07373  0.382453  0.130844            0             0            0
# 32582  0.07373 -0.907717 -2.106022            0             0            0
# 7906   0.07373  1.027538 -0.668037            0             0            0
# 2494   0.07373  1.672623  0.450397            0             0            0
# ...        ...       ...       ...          ...           ...          ...
# 204    0.07373  1.672623 -1.946246            0             0            0
# 9140   0.07373  1.027538  0.769949            0             0            0
# 7425   0.07373  1.027538  0.450397            0             0            0
# 7019   0.07373  1.027538  1.089502            0             0            1
# 7019                     0                      0
# 5142                     0                      1
# 32448                    0                      1
# 8068                     1                      0
# 9285                     0                      0
# 5141                     0                      0
# 30258                    0                      0
# 15975                    0                      1
# 16292                    1                      0
# 19920                    0                      1
# 38318                    0                      0
# 25835                    1                      0
# 29137                    0                      1
# 34249                    0                      0
# 24928                    0                      0
# 33061                    0                      0
# 15839                    0                      1
# 1005                     0                      0
# 41080                    0                      1
# 36395                    0                      0
# 35517                    0                      0
# 5509                     0                      1
# 40781                    0                      0
# 11099                    0                      0
# 27598                    1                      0
# 9028                     0                      0
# 33881                    0                      0
#
# [2700 rows x 2889 columns]

# %% [markdown]
# # Проверяем качество классификатора

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %% [markdown]
# Ошибки на обучающей и тестовой выборках

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.4244697601185515 0.6685185185185185

# %%
print(mlp_model.score(X_train, y_train), mlp_model.score(X_test, y_test))
# Out:
# 0.5755302398814486 0.3314814814814815

# %%
print(1 - mlp_model.score(X_test, y_test))
# Out:
# 0.6685185185185185

# %% [markdown]
# ### Подбор гиперпараметров

# %% [markdown]
# # Оптимальное количество нейронов

# %%
neron_arr = np.arange(95,105)
test_err_ner = []
train_err_ner = []
for neron in neron_arr:
    mlp_model_ner = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (neron,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model_ner.fit(X_train, y_train)

    y_train_pred_ner = mlp_model_ner.predict(X_train)
    y_test_pred_ner = mlp_model_ner.predict(X_test)
    train_err_ner.append(np.mean(y_train != y_train_pred_ner))
    test_err_ner.append(np.mean(y_test != y_test_pred_ner))

# %%
plt.plot(neron_arr, test_err_ner, 'b-o', label = 'test')
plt.plot(neron_arr, train_err_ner, 'r-o', label = 'train')
plt.xlim([np.min(neron_arr), np.max(neron_arr)])
plt.title('Error vs. neron')
plt.xlabel('neron')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err_ner)
min_test_err = np.min(test_err_ner)
print(min_train_err, min_test_err)
# Out:
# 0.47987170979871707 0.6547699214365881

# %%
nerron_opt = neron_arr[test_err_ner == min_test_err]
print(nerron_opt)
# Out:
# [98]

# %% [markdown]
# ### Матрица рассогласования

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test_pred, y_test))
# Out:
# [[350  85  57  72  34  52  43]
#  [116 198 106 141  93 102 141]
#  [ 31  89 108  79  40  37  37]
#  [ 65 118  94 199  48  95  91]
#  [ 27  62  41  45 226  54  44]
#  [ 54 101  61 111  78 127  83]
#  [ 43  97  46  99  57  95 183]]

# %%
M = confusion_matrix(y_test_pred, y_test)
M = np.sqrt(M)
plt.imshow(M, interpolation = 'nearest')
plt.set_cmap('binary')
plt.xticks(range(2))
plt.yticks(range(2))
plt.xlabel("true label")
plt.ylabel("predicted label")
plt.colorbar()
pass

# %% [markdown]
# ### Другие метрики качества:

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_test_pred))
# Out:
#                     precision    recall  f1-score   support
#
#     Drug Violation       0.51      0.51      0.51       686
# Investigate Person       0.22      0.26      0.24       750
#      Property Lost       0.26      0.21      0.23       513
#     Simple Assault       0.28      0.27      0.27       746
#              Towed       0.45      0.39      0.42       576
#          Vandalism       0.21      0.23      0.22       562
#    Verbal Disputes       0.30      0.29      0.29       622
#
#        avg / total       0.32      0.31      0.31      4455

# %%
counter = 0
for i in X_test.index:
    x = X_test.loc[i, :]
    dig = y_test[i]
    dig_pred = mlp_model.predict([x])
    if dig_pred != dig:
        counter += 1
print("Количество ошибок: "+ str(counter))
print("Размер тестовой выборки: " + str(len(X_test)))
# Out:
# Количество ошибок: 3064
# Размер тестовой выборки: 4455

# %% [markdown]
# ### Задание №3

# %% [markdown]
# #### Обучить на ваших данных 1) random forests, 2) extremely random forests, 3) adaboost, 4) gradient boosted trees. Постройте графики зависимости ошибки (на тестовой и обучающейся выборках, а также oob-ошибку) от количества используемых деревьев. Наблюдается ли переобучение/недообучение? Сделайте выводы. Все нужно продолжать в том же ноутбуке, в котором вы делали задание №1.

# %% [markdown]
# ### Random Forests

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
N_train, _ = X_train.shape 

print(N_train, N_test)
# Out:
# 9042 4455

# %% [markdown]
# Обучим классификатор вида Random Forest c числом деревьев = 100

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 100)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train)
print( err_test)
# Out:
# 0.013050210130502102
# 0.6594837261503929

# %% [markdown]
# Видим, что ошибка на обучающей выборке сильно меньше, чем на тестовой, т.о. имеет место переобучение.

# %% [markdown]
# Построим график зависимости ошибок от количества деревьев

# %%
trees_arr = np.arange(50, 150, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.min(trees_arr), np.max(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print( min_train_err)
print( min_test_err)
# Out:
# 0.013050210130502102
# 0.652749719416386

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == min_test_err]
print(trees_opt)
# Out:
# [140]

# %% [markdown]
# ## Extremely Random Forests

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
N_train, _ = X_train.shape 

print(N_train, N_test)
# Out:
# 9042 4455

# %% [markdown]
# Обучим классификатор вида Extremely Random Forest c числом деревьев = 100

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100)
ert.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train)
print(err_test)
# Out:
# 0.013050210130502102
# 0.6686868686868687

# %% [markdown]
# Видим, что ошибка на обучающей выборке сильно меньше, чем на тестовой, т.о. имеет место переобучение.
#
# Построим график зависимости ошибок от количества деревьев

# %%
trees_arr = np.arange(50, 150, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    ert = ensemble.ExtraTreesClassifier(n_estimators = trees, oob_score=True, bootstrap=True)
    ert.fit(X_train, y_train)
    train_err.append(np.mean(y_train != ert.predict(X_train)))
    test_err.append(np.mean(y_test  != ert.predict(X_test)))
    oob_err.append(1 - ert.oob_score_)

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.min(trees_arr), np.max(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err)
print(min_test_err)
# Out:
# 0.013050210130502102
# 0.6594837261503929

# %% [markdown]
# Оптимальное количество деревьев

# %%
trees_opt = trees_arr[test_err == min_test_err]
print(trees_opt)
# Out:
# [ 80 140]

# %% [markdown]
# ## AdaBoost

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
N_train, _ = X_train.shape 

print(N_train, N_test)
# Out:
# 9042 4455

# %% [markdown]
# Обучим классификатор вида AdaBoost c числом деревьев = 100

# %%
ab = ensemble.AdaBoostClassifier(n_estimators = 100)
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME.R', base_estimator=None,
#           learning_rate=1.0, n_estimators=100, random_state=None)

# %%
err_train = np.mean(y_train != ab.predict(X_train))
err_test  = np.mean(y_test  != ab.predict(X_test))

print(err_train)
print(err_test)
# Out:
# 0.6885644768856448
# 0.694949494949495

# %% [markdown]
# Видим, что ошибки на обучающей и тестовой выборках примерно одинаковы. Переобучение не наблюдается
#
# Построим график зависимости ошибок от количества деревьев

# %%
trees_arr = np.arange(50, 150, 5)
test_err = []
train_err = []
for trees in trees_arr:
    ab = ensemble.AdaBoostClassifier(n_estimators = trees)
    ab.fit(X_train, y_train)
    train_err.append(np.mean(y_train != ab.predict(X_train)))
    test_err.append(np.mean(y_test  != ab.predict(X_test)))

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(trees_arr), np.max(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err)
print(min_test_err)
# Out:
# 0.6798274717982747
# 0.6915824915824916

# %% [markdown]
# Оптимальное количество деревьев:

# %%
trees_opt = trees_arr[test_err == min_test_err]
print(trees_opt)
# Out:
# [125]

# %% [markdown]
# ## Gradient boosted trees

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
N_train, _ = X_train.shape 

print(N_train, N_test)
# Out:
# 9042 4455

# %% [markdown]
# Обучим классификатор вида Gradient Boosted Trees c числом деревьев = 100

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 100)
gbt.fit(X_train, y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               presort='auto', random_state=None, subsample=1.0, verbose=0,
#               warm_start=False)

# %%
err_train = np.mean(y_train != gbt.predict(X_train))
err_test  = np.mean(y_test  != gbt.predict(X_test))

print(err_train)
print(err_test)
# Out:
# 0.5565140455651405
# 0.6758698092031425

# %% [markdown]
# Видим, что ошибка на обучающей выборке сильно меньше, чем на тестовой, т.о. имеет место переобучение

# %% [markdown]
# Построим график зависимости ошибок от количества деревьев

# %%
trees_arr = np.arange(50, 150, 5)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.min(trees_arr), np.max(trees_arr)])
plt.title('Error vs. Trees')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное знаение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err)
print(min_test_err)
# Out:
# 0.5259898252598982
# 0.6725028058361392

# %%
trees_opt = trees_arr[test_err == min_test_err][0]
print(trees_opt)
# Out:
# 135

# %% [markdown]
# ### Задание №4

# %% [markdown]
# Для ваших данных применить PCA для сокращения размерности пространства признаков. К новым данным применить любой классификатор. Построить графики зависимости ошибки на тестовой и обучающей выборках в зависимости от количества используемых компонент. Найти наилучшее значение количества используемых главных компонент.

# %%
from sklearn.decomposition import PCA
pca = PCA( n_components = 10)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
result_pca=pca.transform(X)
result_pca.shape
# Out:
# (13497, 10)

# %% [markdown]
# Разбиваем данные на обучающую и тестовую выборки

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(result_pca, y, test_size = 0.33, random_state = 7)
N_test, _ = X_test.shape
N_train, _ = X_train.shape

# %% [markdown]
# Воспользуемся классификатором Extremely Random Forests с числом деревьев 100

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100)
ert.fit(X_train, y_train)
# Out:
# ExtraTreesClassifier(bootstrap=False, class_weight=None, criterion='gini',
#            max_depth=None, max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %%
err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train)
print(err_test)
# Out:
# 0.013160805131608052
# 0.7317620650953984

# %% [markdown]
# Видим, что ошибка на обучающей выборке сильно меньше, чем на тестовой, т.о. имеет место переобучение

# %% [markdown]
# Построим график зависимости ошибок от количества компонент в методе

# %%
components_arr = np.arange(1, 9, 1)
test_err = []
train_err = []
oob_err = []
for components in components_arr:
    pca = PCA(n_components = components)
    X_pca_train = pca.fit_transform(X_train)
    X_pca_test = pca.transform(X_test)
    ert = ensemble.ExtraTreesClassifier(n_estimators = 100, oob_score=True, bootstrap=True)
    ert.fit(X_pca_train, y_train)
    train_err.append(np.mean(y_train != ert.predict(X_pca_train)))
    test_err.append(np.mean(y_test  != ert.predict(X_pca_test)))
    oob_err.append(1 - ert.oob_score_)
plt.plot(components_arr, train_err, 'b-o', label = 'train')
plt.plot(components_arr, test_err, 'r-o', label = 'test')
plt.plot(components_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.min(components_arr), np.max(components_arr)])
plt.title('Error vs. Components')
plt.xlabel('components')
plt.ylabel('error')
plt.legend()
pass

# %%
print(components_arr)
# Out:
# [1 2 3 4 5 6 7 8]

# %% [markdown]
# Из графика видно, что при числе компонент < 6 ошибка на тестовой выборке и oob ошибка сильно увеличиваются

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)

print (min_train_err)
print (min_test_err)
# Out:
# 0.013160805131608052
# 0.7254769921436588

# %% [markdown]
# Оптимальное количество компонент:

# %%
components_opt = components_arr[test_err == min_test_err]
components_opt = components_opt[0]
print(components_opt)
# Out:
# 8
